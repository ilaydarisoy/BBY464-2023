# %%
from traitlets.traitlets import MetaHasTraits
<?xml version="1.0" encoding="UTF-8"?>
  <CATALOG>
    <book>
    <TITLE>Kaybolan Baglar</TITLE>
    <AUTHOR>Johann Hari</AUTHOR>
    <PUBLISHER>Metis</PUBLISHER>
    <ISBN>9786053161639</ISBN>
    <DATE OF PUBLICATION>2019</DATE OF PUBLICATION>
    <PRICE>103,55</PRICE>
    <URL>https://www.idefix.com/kitap/kaybolan-baglar-depresyonun-gercek-nedenleri-ve-beklenmedik-cozumler/egitim-basvuru/psikoloji-bilimi/urunno=0001814340001</URL>
    </book>

    <book>
    <TITLE>Curumenin Kitabi</TITLE>
    <AUTHOR>Emil Michel Cioran</AUTHOR>
    <PUBLISHER>Metis</PUBLISHER>
    <ISBN>9789753422666</ISBN>
    <DATE OF PUBLICATION>2000</DATE OF PUBLICATION>
    <PRICE>58,95</PRICE>
    <URL>https://www.idefix.com/Kitap/Curumenin-Kitabi/Felsefe/Felsefe-Bilimi/urunno=0000000077396</URL>
    </book>

   <book>
   <TITLE>İrade Terbiyesi</TITLE>
   <AUTHOR>Jules Payot</AUTHOR>
   <PUBLISHER>Koridor</PUBLISHER>
   <ISBN>9786057572509</ISBN>
   <DATE OF PUBLICATION>2020</DATE OF PUBLICATION>
   <PRICE>56,25</PRICE>
   <URL>https://www.idefix.com/Kitap/Irade-Terbiyesi/Felsefe/Felsefe-Bilimi/urunno=0001869781001</URL>
   </book>

   <book>
   <TITLE>Yurumenin Felsefesi</TITLE>
   <AUTHOR>Frederic Gros</AUTHOR>
   <PUBLISHER>Kolektif</PUBLISHER>
   <ISBN>9786055029647</ISBN>
   <DATE OF PUBLICATION>2020</DATE OF PUBLICATION>
   <PRICE>50,15</PRICE>
   <URL>https://www.idefix.com/Kitap/Yurumenin-Felsefesi/Frederic-Gros/Felsefe/Felsefe-Bilimi/urunno=0001686744001</URL>
   </book>

   <book>
   <TITLE>Yaratma Cesareti</TITLE>
   <AUTHOR>Rollo May</AUTHOR>
   <PUBLISHER>Metis</PUBLISHER>
   <ISBN>9789753421904</ISBN>
   <DATE OF PUBLICATION>2007</DATE OF PUBLICATION>
   <PRICE>53,25</PRICE>
   <URL>https://www.idefix.com/Kitap/Yaratma-Cesareti/Felsefe/Felsefe-Bilimi/urunno=0000000068248</URL>
   </book>

   <book>
   <TITLE>Spinoza nin Sevinci Nereden Geliyor</TITLE>
   <AUTHOR>Cetin Balanuye</AUTHOR>
   <PUBLISHER>Ayrinti</PUBLISHER>
   <ISBN>9786053141525</ISBN>
   <DATE OF PUBLICATION>2017</DATE OF PUBLICATION>
   <PRICE>44,20</PRICE>
   <URL>https://www.idefix.com/Kitap/Spinozanin-Sevinci-Nereden-Geliyor/Cetin-Balanuye/Felsefe/Felsefe-Bilimi/urunno=0001691317001</URL>
   </book>

   <book>
   <TITLE>Kendini İyileştirme İşi Nasıl Yapılır?</TITLE>
   <AUTHOR>Nicole Lepera</AUTHOR>
   <PUBLISHER>Butik</PUBLISHER>
   <ISBN>9786057038050</ISBN>
   <DATE OF PUBLICATION>2021</DATE OF PUBLICATION>
   <PRICE>108,15</PRICE>
   <URL>https://www.idefix.com/Kitap/Kendini-Iyilestirme-Isi-Nasil-Yapilir/Nicole-Lepera/Egitim-Basvuru/Kisisel-Gelisim/urunno=0001919933001</URL>
   </book>

   <book>
   <TITLE>Hayat Çözülecek Bir Problem Değil Yaşanacak Bir Hakikattir</TITLE>
   <AUTHOR>Soren Kierkegaard</AUTHOR>
   <PUBLISHER>Destek</PUBLISHER>
   <ISBN>9786053119883</ISBN>
   <DATE OF PUBLICATION>2020</DATE OF PUBLICATION>
   <PRICE>20,55</PRICE>
   <URL>https://www.idefix.com/Kitap/Soren-Kierkegaard-Hayat-Cozulecek-Bir-Problem-Degil-Yasanacak-Bir-Hakikattir/Felsefe/Felsefe-Bilimi/urunno=0001891744001</URL>
   </book>

   <book>
   <TITLE>Hayatın Gizli Hazları</TITLE>
   <AUTHOR>Theodore Zeldin</AUTHOR>
   <PUBLISHER>Ayrıntı</PUBLISHER>
   <ISBN>9786053141280</ISBN>
   <DATE OF PUBLICATION>2016</DATE OF PUBLICATION>
   <PRICE>101,80</PRICE>
   <URL>https://www.idefix.com/Kitap/Hayatin-Gizli-Hazlari/Theodore-Zeldin/Felsefe/Felsefe-Bilimi/urunno=0000000712885</URL>
   </book>

   <book>
   <TITLE>Sevginin İşleri</TITLE>
   <AUTHOR>Soren Kierkegaard</AUTHOR>
   <PUBLISHER>Pinhan</PUBLISHER>
   <ISBN>9786057768162</ISBN>
   <DATE OF PUBLICATION>2020</DATE OF PUBLICATION>
   <PRICE>138,40</PRICE>
   <URL>https://www.idefix.com/Kitap/Sevginin-Isleri/Felsefe/Felsefe-Bilimi/urunno=0001868795001</URL>
   </book>
  </CATALOG>
# Out:
#   File "<ipython-input-12-ea50e74ea2fb>", line 1
#     <?xml version="1.0" encoding="UTF-8"?>
#     ^
# SyntaxError: invalid syntax
